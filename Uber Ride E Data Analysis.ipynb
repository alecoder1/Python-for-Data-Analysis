# %% [markdown]
# ## Objective
#
# - To fetch insights from the behavoir of a common Uber customer.

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

import os

# %% [markdown]
# ### Loading dataset

# %%
df = pd.read_csv("data/My Uber Drives - 2016.csv")
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
print(df.shape)
df.dtypes
# Out:
# (1156, 7)
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %% [markdown]
# - There are 6 categorical vars and I numeric vaiable. Here START_DATE and END_DATE are in oject type. We need to convert them back into datetime variable.

# %% [markdown]
# ### Checking for null values

# %%
df.isna().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
df[df['END_DATE*'].isna()]
# Out:
#      START_DATE* END_DATE* CATEGORY* START* STOP*   MILES* PURPOSE*
# 1155      Totals       NaN       NaN    NaN   NaN  12204.7      NaN

# %% [markdown]
# - As we can see this row contains wrong data for the most of the columns. We will delete it.

# %%
# dropping row containing null values
df.drop(df[df['END_DATE*'].isna()].index, axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# - Now we have null data only in purpose column. As we have more than 55% data missing. So I am dropping this columns and excluding this from the analysis. You may also delete the null value rows and include this column in the analysis.
# sns.countplot(df['PURPOSE*'], order=df['PURPOSE*'].value_counts().index

# %%
# dropping purpose

df.drop(['PURPOSE*'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*
# 0     5.1
# 1     5.0
# 2     4.8
# 3     4.7
# 4    63.7

# %% [markdown]
# ## Checking for duplicated rows

# %%
df[df.duplicated()]
# Out:
#          START_DATE*        END_DATE* CATEGORY*  START* STOP*  MILES*
# 492  6/28/2016 23:34  6/28/2016 23:59  Business  Durham  Cary     9.9

# %% [markdown]
# ### We will remover this duplicated row

# %%
df.drop(df[df.duplicated()].index, axis=0, inplace=True)

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*]
# Index: []

# %% [markdown]
# ### Converting start_date & end_date cols into datetime

# %%
df['START_DATE*'] = pd.to_datetime(df['START_DATE*'], format='%m/%d/%Y %H:%M')
df['END_DATE*'] = pd.to_datetime(df['END_DATE*'], format='%m/%d/%Y %H:%M')

df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# dtype: object

# %% [markdown]
# ## EDA
#
# - univariate summarize one variable at a time.
#
#
# - category

# %%
df['CATEGORY*'].unique()
# Out:
# array(['Business', 'Personal'], dtype=object)

# %% [markdown]
# - There are 2 ride-categories.. Business for work related & Personal for personal travel.

# %%
df[['CATEGORY*', 'MILES*']].groupby(['CATEGORY*']).agg(tot_miles=('MILES*', 'sum'))
# Out:
#            tot_miles
# CATEGORY*
# Business     11477.1
# Personal       717.7

# %%
plt.figure(figsize=(10, 2))
df[['CATEGORY*','MILES*']].groupby(['CATEGORY*']).agg(tot_miles=('MILES*','sum')).plot(kind='bar')
plt.xlabel('category')
plt.ylabel('Total Miles')
plt.title('Total Miles Per Category')
# Out:
# Text(0.5, 1.0, 'Total Miles Per Category')

# %% [markdown]
# - Users mainly use Uber cabs for their Business purposes. Around 94% miles was consumed during Business trips. * Only 6% was consumed for personal trips.

# %% [markdown]
# ### START*

# %%
len(df['START*'].unique())
# Out:
# 177

# %% [markdown]
# - There are 177 unique starting points

# %%
# Top 10 Start places

df['START*'].value_counts(ascending=False)[:10]
# Out:
# START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Lahore               36
# Durham               36
# Raleigh              28
# Kar?chi              27
# Westpark Place       17
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 7))
df['START*'].value_counts(ascending=False)[:10].plot(kind='barh',
                                                   ylabel='Places',
                                                   xlabel='Pickup Count',
                                                   title='Top 10 Pickup Places')
# Out:
# <Axes: title={'center': 'Top 10 Pickup Places'}, xlabel='Pickup Count', ylabel='Places'>

# %% [markdown]
# -- Cary is the most popular Starting point for this user.

# %% [markdown]
# ## STOP*

# %%
len(df['STOP*'].unique())
# Out:
# 188

# %% [markdown]
# - There are 188 unique Drop Points (DESTINATION).

# %%
df['STOP*'].value_counts(ascending=False)[:10]
# Out:
# STOP*
# Cary                202
# Unknown Location    149
# Morrisville          84
# Whitebridge          65
# Islamabad            58
# Durham               36
# Lahore               36
# Raleigh              29
# Kar?chi              26
# Apex                 17
# Name: count, dtype: int64

# %%
df['STOP*'].value_counts(ascending=False)[:10].plot(kind='barh',
                                                   ylabel='Places',
                                                   xlabel='Drop Count',
                                                   title='Top 10 Drop Places')
# Out:
# <Axes: title={'center': 'Top 10 Drop Places'}, xlabel='Drop Count', ylabel='Places'>

# %% [markdown]
# - Cary is the most popular Stop place for this user. Maybe his home is in Cary (as mostly start & Stop are from here)

# %%
df[df['START*']=='Unknown Location']['START*'].value_counts()
# Out:
# START*
# Unknown Location    148
# Name: count, dtype: int64

# %%
df[df['STOP*']=='Unknown Location']['STOP*'].value_counts()
# Out:
# STOP*
# Unknown Location    149
# Name: count, dtype: int64

# %% [markdown]
# ### MILES*

# %%
sns.histplot(df['MILES*'], kde=True)
# Out:
# <Axes: xlabel='MILES*', ylabel='Count'>

# %% [markdown]
# - Miles data is Rightly Skewed.

# %%
df.describe().T
# Out:
#               count                           mean                  min  \
# START_DATE*    1154  2016-07-17 00:07:01.611784960  2016-01-01 21:11:00
# END_DATE*      1154  2016-07-17 00:30:16.117850880  2016-01-01 21:17:00
# MILES*       1154.0                      10.567418                  0.5
#
#                              25%                  50%                  75%  \
# START_DATE*  2016-03-31 20:23:30  2016-07-21 17:29:30  2016-10-27 21:16:15
# END_DATE*    2016-03-31 20:52:00  2016-07-21 17:37:00  2016-10-27 21:34:30
# MILES*                       2.9                  6.0                 10.4
#
#                              max        std
# START_DATE*  2016-12-31 22:08:00        NaN
# END_DATE*    2016-12-31 23:51:00        NaN
# MILES*                     310.3  21.588452

# %% [markdown]
# ### Multivariate Analysis

# %%
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*
# 0      Fort Pierce     5.1
# 1      Fort Pierce     5.0
# 2      Fort Pierce     4.8
# 3      Fort Pierce     4.7
# 4  West Palm Beach    63.7

# %%
df.groupby(['START*','STOP*'])['MILES*'].apply(print)
# Out:
# 910    2.2
# Name: (Agnew, Agnew), dtype: float64
# 906    4.3
# Name: (Agnew, Cory), dtype: float64
# 908    2.2
# 911    2.4
# Name: (Agnew, Renaissance), dtype: float64
# 879    15.2
# Name: (Almond, Bryson City), dtype: float64
# 646    1.0
# 825    3.3
# Name: (Apex, Apex), dtype: float64
# 58      5.5
# 60      5.7
# 80      5.7
# 173     5.6
# 410     7.2
# 565     5.5
# 616     4.6
# 647     6.0
# 826     5.3
# 978     5.4
# 1014    5.3
# 1033    8.8
# 1045    4.7
# Name: (Apex, Cary), dtype: float64
# 855    2.2
# Name: (Apex, Eagle Rock), dtype: float64
# 1001    9.0
# Name: (Apex, Holly Springs), dtype: float64
# 469    17.0
# Name: (Arabi, Metairie), dtype: float64
# 621    4.9
# Name: (Arlington, Washington), dtype: float64
# 613    1.3
# Name: (Arlington Park at Amberly, Lexington Park at Amberly), dtype: float64
# 881    195.9
# Name: (Asheville, Mebane), dtype: float64
# 871    91.8
# Name: (Asheville, Topton), dtype: float64
# 232    136.0
# ...

# %%
df.groupby(['START*','STOP*'])['MILES*'].sum().sort_values(ascending=False)[1:11]
# Out:
# START*            STOP*
# Morrisville       Cary                395.7
# Cary              Durham              390.0
#                   Morrisville         380.0
# Raleigh           Cary                365.7
# Cary              Raleigh             336.5
# Durham            Cary                324.5
# Latta             Jacksonville        310.3
# Islamabad         Unknown Location    267.0
# Cary              Cary                255.9
# Unknown Location  Islamabad           243.8
# Name: MILES*, dtype: float64

# %% [markdown]
# - Cary-Durham & Cary-Morrisville and viceversa are the farthest distance ride.
#
# - Checking for Round Trip

# %%
def is_roundtrip(df):
    if df['START*'] == df['STOP*']:
        return 'YES'
    else:
        return 'NO'
    
df['ROUND_TRIP*'] = df.apply(is_roundtrip, axis=1)

sns.countplot(x='ROUND_TRIP*',data=df, order=df['ROUND_TRIP*'].value_counts().index)
# Out:
# <Axes: xlabel='ROUND_TRIP*', ylabel='count'>

# %%
df['ROUND_TRIP*'].value_counts()
# Out:
# ROUND_TRIP*
# NO     866
# YES    288
# Name: count, dtype: int64

# %% [markdown]
# - User mostly take sinle-trip Uber riders. *Around 75% trip is single-trip and 25% are Round-trip.*

# %% [markdown]
# ### Calculating Ride Duration

# %%
df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# ROUND_TRIP*            object
# dtype: object

# %%
df['Ride_duration'] = df['END_DATE*'] - df['START_DATE*']
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES* ROUND_TRIP*   Ride_duration
# 0      Fort Pierce     5.1         YES 0 days 00:06:00
# 1      Fort Pierce     5.0         YES 0 days 00:12:00
# 2      Fort Pierce     4.8         YES 0 days 00:13:00
# 3      Fort Pierce     4.7         YES 0 days 00:14:00
# 4  West Palm Beach    63.7          NO 0 days 01:07:00

# %% [markdown]
# ## Converting Ride_duration into Minute
#
# - This is a Python Lamda function that takes a single argument "x".
# - The function first calls the to_pytimedelta() method on pd.Timedelta, which converts the input x into a datetime.timedelta object.
#
# - The function then calculates the total number of minutes in the timedelta object, which is done by first getting the number of days using the days attribute and multipying it by 24 hours and 60 minutes per hour. Then, the number of seconds is divided by 60 to convert them into minutes, and added to the previously calculated number of minutes. The final result is the total numer of minutes in the timedelta object.
#
# - This function could be used to calculate the duration of a time interval in  minutes, which could be useful in a variety of applications such as analyzing time-series data or calculating the length of time between two events.
#
# - Note that this function assumes that the input x is a valid pd.Timedelta object and may raise errors if the input is not in the expected format.

# %%
# using datetime.Timedelta
# => https://pandas.pydata.org/pandas-docs/stable/user_guide/timedeltas.html
df.loc[:, 'Ride_duration'] = df['Ride_duration'].apply(
    lambda x: pd.Timedelta.to_pytimedelta(x).days/(24*60) + pd.Timedelta.to_pytimedelta(x).seconds/60)
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES* ROUND_TRIP*  Ride_duration
# 0      Fort Pierce     5.1         YES            6.0
# 1      Fort Pierce     5.0         YES           12.0
# 2      Fort Pierce     4.8         YES           13.0
# 3      Fort Pierce     4.7         YES           14.0
# 4  West Palm Beach    63.7          NO           67.0

# %%
# Capture Hour, Month & Year of Ride in a separate column

df['month'] = pd.to_datetime(df['START_DATE*']).dt.month
df['Year'] = pd.to_datetime(df['START_DATE*']).dt.year
df['Day'] = pd.to_datetime(df['START_DATE*']).dt.day
df['Hour'] = pd.to_datetime(df['START_DATE*']).dt.hour

df['day_of_week'] = pd.to_datetime(df['START_DATE*']).dt.dayofweek
days = {0: 'Mon',1: 'Tue', 2: 'Wed', 3: 'Thur', 4: 'Fri', 5: 'Sat', 6: 'Sun'}

df['day_of_week'] = df['day_of_week'].apply(lambda x: days[x])

df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES* ROUND_TRIP*  Ride_duration  month  Year  Day  Hour  \
# 0      Fort Pierce     5.1         YES            6.0      1  2016    1    21
# 1      Fort Pierce     5.0         YES           12.0      1  2016    2     1
# 2      Fort Pierce     4.8         YES           13.0      1  2016    2    20
# 3      Fort Pierce     4.7         YES           14.0      1  2016    5    17
# 4  West Palm Beach    63.7          NO           67.0      1  2016    6    14
#
#   day_of_week
# 0         Fri
# 1         Sat
# 2         Sat
# 3         Tue
# 4         Wed

# %% [markdown]
# - Adding month name instead of month number

# %%
## Replaceing non-numeric values with a placeholder value(-1) before conversion

def convert_month_to_abbr(month):
    try:
        return calendar.month_abbr[int(month)]
    except ValueError:
        return -1  # Or any other placeholder

df['month'] = df['month'].apply(convert_month_to_abbr)

# %%
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES* ROUND_TRIP*  Ride_duration month  Year  Day  Hour  \
# 0      Fort Pierce     5.1         YES            6.0   Jan  2016    1    21
# 1      Fort Pierce     5.0         YES           12.0   Jan  2016    2     1
# 2      Fort Pierce     4.8         YES           13.0   Jan  2016    2    20
# 3      Fort Pierce     4.7         YES           14.0   Jan  2016    5    17
# 4  West Palm Beach    63.7          NO           67.0   Jan  2016    6    14
#
#   day_of_week
# 0         Fri
# 1         Sat
# 2         Sat
# 3         Tue
# 4         Wed

# %%
# droppig month_abbr

# df.drop(['month_abbr'],axis=1,inplace=True)

#df.head()

# %% [markdown]
# ### Total Rides/Month

# %%
print(df['month'].value_counts())
# Out:
# month
# Dec    146
# Aug    133
# Nov    122
# Feb    115
# Mar    113
# Jul    112
# Jun    107
# Oct    106
# Jan     61
# Apr     54
# May     49
# Sep     36
# Name: count, dtype: int64

# %%
sns.countplot(x='month',data=df, order=pd.value_counts(df['month']).index, hue='CATEGORY*')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %% [markdown]
# - Most number of rides were in month of December (all of them were Business Trips)
# - Top 5 months aving most trips were: December, August, November, February & March.
# - Uber Ride was used at Fe, Mar,Jul, Jun & Aor for personal trips.

# %%
sns.countplot(x='day_of_week',data=df, order=pd.value_counts(df['day_of_week']).index, hue='CATEGORY*')
# Out:
# <Axes: xlabel='day_of_week', ylabel='count'>

# %% [markdown]
# - FRIDAY was the day at which Uber Rides were mostly used
#
# ### Average distance covered/month

# %%
## Handling non-numeric values using the replacement with a placeholder value eg.,1

def convert_to_numeric (x):
    try:
        return float(x)
    except ValueError:
        return -1 # or any other placeholder
    
df['MILES*'] = df['MILES*'].apply(convert_to_numeric)
df.groupby('month')['MILES*'].mean().sort_values(ascending=False).plot(kind='bar')

plt.axhline(df['MILES*'].mean(), linestyle='--',
           color='red',
           label='Mean Distance')
plt.legend()
plt.show()

# %% [markdown]
# - User's Longest ride were on April & shortest were on November.

# %%
sns.countplot(x='Hour', data=df, order=pd.value_counts(df['Hour']).index, 
             hue='CATEGORY*')
# Out:
# <Axes: xlabel='Hour', ylabel='count'>

# %% [markdown]
# - Maximum number of trips were on Evening & at Noon.
#
# ### Calculating TRIP Speed.

# %%
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES* ROUND_TRIP*  Ride_duration month  Year  Day  Hour  \
# 0      Fort Pierce     5.1         YES            6.0   Jan  2016    1    21
# 1      Fort Pierce     5.0         YES           12.0   Jan  2016    2     1
# 2      Fort Pierce     4.8         YES           13.0   Jan  2016    2    20
# 3      Fort Pierce     4.7         YES           14.0   Jan  2016    5    17
# 4  West Palm Beach    63.7          NO           67.0   Jan  2016    6    14
#
#   day_of_week
# 0         Fri
# 1         Sat
# 2         Sat
# 3         Tue
# 4         Wed

# %%
df['Duration_hours'] = df['Ride_duration']/60

df['Speed_KM'] = df['MILES*']/df['Duration_hours']

df.head(2)
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*        STOP*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce  Fort Pierce
#
#    MILES* ROUND_TRIP*  Ride_duration month  Year  Day  Hour day_of_week  \
# 0     5.1         YES            6.0   Jan  2016    1    21         Fri
# 1     5.0         YES           12.0   Jan  2016    2     1         Sat
#
#    Duration_hours  Speed_KM
# 0             0.1      51.0
# 1             0.2      25.0

# %%
fig, ax = plt.subplots()
sns.histplot(x='Speed_KM', data=df, kde=True, ax=ax)
# Out:
# <Axes: xlabel='Speed_KM', ylabel='Count'>

# %% [markdown]
# - Speed is right skewed.
#
# ## Conclusion
# - User mainly uses Uber cabs for its Business purpose.
#     - Around 94% miles was consumed during Business trips.
#     - Only 6% miles were consumed during personal trips.
#
# - There are 177 unique starting points.
#     - Cary is most popular starting point for this driver.
# - There are 188 unique Stop points.
#     - Cary is the most popular drop point for this driver.
# - Cary-Durham & Cary-Morrisville and vice versa are the User's longest distance Uber ride.
# - User usually takes single-trip Uber riders.
#     - Around 75% trip is single-trip and 25% are Round-Trip.
# - User's most number of rides were in month of December & Least were in September.
# - Friday has maximum number of trips.
# - Afternoons and evenings seem to have th maximum number of trips.
# - User's Longest ride were on April & Shortest were on November.
